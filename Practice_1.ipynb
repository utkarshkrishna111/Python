# %%
import numpy as np
import pandas as pd

# %%
laliga= pd.read_csv(r"C:\Users\utkar\Desktop\Python Files\laliga.csv",skiprows=1)

# %%
laliga
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      -           -        -          -
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %%
laliga = laliga.replace('-', 0)

# %%
laliga
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      0           0        0          0
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %%
laliga.columns
# Out:
# Index(['Pos', 'Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Debut',
#        'Since/LastApp', 'BestPosition'],
#       dtype='object')

# %%
laliga.index
# Out:
# RangeIndex(start=0, stop=61, step=1)

# %%
laliga.size
# Out:
# 1220

# %%
laliga.shape
# Out:
# (61, 20)

# %%
laliga.index
# Out:
# RangeIndex(start=0, stop=61, step=1)

# %%
laliga.index = laliga['Team']

# %%
laliga.index
# Out:
# Index(['Real Madrid', 'Barcelona', 'Atletico Madrid', 'Valencia',
#        'Athletic Bilbao', 'Sevilla', 'Espanyol', 'Real Sociedad', 'Zaragoza',
#        'Real Betis', 'Deportivo La Coruna', 'Celta Vigo', 'Valladolid',
#        'Racing Santander', 'Sporting Gijon', 'Osasuna', 'Malaga', 'Oviedo',
#        'Mallorca', 'Las Palmas', 'Villarreal', 'Granada', 'Rayo Vallecano',
#        'Elche', 'Getafe', 'Hercules', 'Tenerife', 'Murcia', 'Alaves',
#        'Levante', 'Salamanca', 'Sabadell', 'Cadiz', 'Logrones', 'Castellon',
#        'Albacete', 'Almeria', 'Cordoba', 'Compostela', 'Recreativo',
#        'Burgos CF', 'Pontevedra', 'Numancia', 'Eibar', 'Arenas', 'Real Burgos',
#        'Gimnastic', 'Extremadura', 'Merida', 'Alcoyano', 'Jaen', 'Real Union',
#        'AD Almeria', 'Europa', 'Lleida', 'Leganes', 'Xerez', 'Condal',
#        'Atletico Tetuan', 'Cultural Leonesa', 'Girona'],
#       dtype='object', name='Team')

# %%
laliga.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points           object
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# dtype: object

# %%
laliga['Champion'].astype(int).idxmax()
# Out:
# 'Real Madrid'

# %%
laliga[laliga=='-'].sum()
# Out:
# C:\Users\utkar\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Pos              0.0
# Team             0.0
# Seasons          0.0
# Points           0.0
# GamesPlayed      0.0
# GamesWon         0.0
# GamesDrawn       0.0
# GamesLost        0.0
# GoalsFor         0.0
# GoalsAgainst     0.0
# Champion         0.0
# Runner-up        0.0
# Third            0.0
# Fourth           0.0
# Fifth            0.0
# Sixth            0.0
# T                0.0
# Debut            0.0
# Since/LastApp    0.0
# BestPosition     0.0
# dtype: float64

# %%
(laliga['Champion'].astype(int)+laliga['Runner-up'].astype(int)+laliga['Third'].astype(int)+laliga['Fourth'].astype(int)+laliga['Fifth'].astype(int)+laliga['Sixth'].astype(int)).idxmax()
# Out:
# 'Barcelona'

# %%
(laliga['Champion'].astype('int')+laliga['Runner-up'].astype('int')+laliga['Third'].astype('int')+laliga['Fourth'].astype('int')+laliga['Fifth'].astype('int')+laliga['Sixth'].astype('int')).max()
# Out:
# 84

# %%
def max_goal_diff_team():
    laliga['Goals_Diff'] = laliga['GoalsFor'].astype('int') - laliga['GoalsAgainst'].astype('int')
    return laliga['Goals_Diff'].idxmax()

# %%
max_goal_diff_team()
# Out:
# 'Real Madrid'

# %%
def min_goal_diff_team():
    laliga['Goals_Diff'] = laliga['GoalsFor'].astype('int') - laliga['GoalsAgainst'].astype('int')
    return laliga['Goals_Diff'].idxmin()

# %%
min_goal_diff_team()
# Out:
# 'Racing Santander'

# %%
laliga.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points           object
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# Goals_Diff        int32
# dtype: object

# %%
laliga['Goals_Diff'].count()
# Out:
# 61

# %%
def goal_diff_count():
    laliga['GoalsDiff'] = laliga['GoalsFor'].astype('int')-laliga['GoalsAgainst'].astype('int')
    return laliga['GoalsDiff']

# %%
goal_diff_count()
# Out:
# Team
# Real Madrid         2807
# Barcelona           2786
# Atletico Madrid     1225
# Valencia             929
# Athletic Bilbao      931
#                     ...
# Xerez                -28
# Condal               -20
# Atletico Tetuan      -34
# Cultural Leonesa     -31
# Girona                 0
# Name: GoalsDiff, Length: 61, dtype: int32

# %%
laliga.head()
# Out:
#                  Pos             Team  Seasons Points GamesPlayed GamesWon  \
# Team
# Real Madrid        1      Real Madrid       86   4385        2762     1647
# Barcelona          2        Barcelona       86   4262        2762     1581
# Atletico Madrid    3  Atletico Madrid       80   3442        2614     1241
# Valencia           4         Valencia       82   3386        2664     1187
# Athletic Bilbao    5  Athletic Bilbao       86   3368        2762     1209
#
#                 GamesDrawn GamesLost GoalsFor GoalsAgainst  ... Third Fourth  \
# Team                                                        ...
# Real Madrid            552       563     5947         3140  ...     8      8
# Barcelona              573       608     5900         3114  ...    12     12
# Atletico Madrid        598       775     4534         3309  ...    16      9
# Valencia               616       861     4398         3469  ...    10     11
# ...

# %%
laliga.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points           object
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# Goals_Diff        int32
# GoalsDiff         int32
# dtype: object

# %%
laliga[laliga['Debut'].between('1930','1980',inclusive=True)][['Team','Debut']]
# Out:
#                                     Team    Debut
# Team
# Valencia                        Valencia  1931-32
# Sevilla                          Sevilla  1934-35
# Zaragoza                        Zaragoza  1939-40
# Real Betis                    Real Betis  1932-33
# Deportivo La Coruna  Deportivo La Coruna  1941-42
# Celta Vigo                    Celta Vigo  1939-40
# Valladolid                    Valladolid  1948-49
# Sporting Gijon            Sporting Gijon  1944-45
# Osasuna                          Osasuna  1935-36
# Malaga                            Malaga  1949-50
# Oviedo                            Oviedo  1933-34
# Mallorca                        Mallorca  1960-61
# Las Palmas                    Las Palmas  1951-52
# Granada                          Granada  1941-42
# Rayo Vallecano            Rayo Vallecano  1977-78
# Elche                              Elche  1959-60
# Hercules                        Hercules  1935-36
# Tenerife                        Tenerife  1961-62
# ...

# %%
laliga.describe()
# Out:
#              Pos    Seasons  BestPosition   Goals_Diff    GoalsDiff
# count  61.000000  61.000000     61.000000    61.000000    61.000000
# mean   31.000000  24.000000      7.081967     0.114754     0.114754
# std    17.752934  26.827225      5.276663   598.095814   598.095814
# min     1.000000   1.000000      1.000000  -525.000000  -525.000000
# 25%    16.000000   4.000000      3.000000  -269.000000  -269.000000
# 50%    31.000000  12.000000      6.000000  -112.000000  -112.000000
# 75%    46.000000  38.000000     10.000000   -34.000000   -34.000000
# max    61.000000  86.000000     20.000000  2807.000000  2807.000000

# %%
laliga.describe().transpose()
# Out:
#               count       mean         std    min    25%    50%   75%     max
# Pos            61.0  31.000000   17.752934    1.0   16.0   31.0  46.0    61.0
# Seasons        61.0  24.000000   26.827225    1.0    4.0   12.0  38.0    86.0
# BestPosition   61.0   7.081967    5.276663    1.0    3.0    6.0  10.0    20.0
# Goals_Diff     61.0   0.114754  598.095814 -525.0 -269.0 -112.0 -34.0  2807.0
# GoalsDiff      61.0   0.114754  598.095814 -525.0 -269.0 -112.0 -34.0  2807.0

# %%
laliga[laliga['Debut'].between('1930','1980')][['Team','Debut']].count()
# Out:
# Team     37
# Debut    37
# dtype: int64

# %%
laliga.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points           object
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# Goals_Diff        int32
# GoalsDiff         int32
# dtype: object

# %%
laliga['WiningPercentage'] = (laliga['GamesWon'].astype('int')/laliga['GamesPlayed'].astype('int'))*100

# %%
laliga['WiningPercentage']
# Out:
# Team
# Real Madrid         59.630702
# Barcelona           57.241130
# Atletico Madrid     47.475134
# Valencia            44.557057
# Athletic Bilbao     43.772629
#                       ...
# Xerez               21.052632
# Condal              23.333333
# Atletico Tetuan     23.333333
# Cultural Leonesa    16.666667
# Girona                    NaN
# Name: WiningPercentage, Length: 61, dtype: float64

# %%
laliga['WiningPercentage']=laliga['WiningPercentage'].fillna(0)

# %%
laliga['WiningPercentage']
# Out:
# Team
# Real Madrid         59.630702
# Barcelona           57.241130
# Atletico Madrid     47.475134
# Valencia            44.557057
# Athletic Bilbao     43.772629
#                       ...
# Xerez               21.052632
# Condal              23.333333
# Atletico Tetuan     23.333333
# Cultural Leonesa    16.666667
# Girona               0.000000
# Name: WiningPercentage, Length: 61, dtype: float64

# %%
laliga['Points']=laliga['Points'].astype(int)

# %%
laliga['Points']
# Out:
# Team
# Real Madrid         4385
# Barcelona           4262
# Atletico Madrid     3442
# Valencia            3386
# Athletic Bilbao     3368
#                     ...
# Xerez                 34
# Condal                22
# Atletico Tetuan       19
# Cultural Leonesa      14
# Girona                 0
# Name: Points, Length: 61, dtype: int32

# %%
laliga.sort_values('Points',ascending=False)[['Team','Points']].head()
# Out:
#                             Team  Points
# Team
# Real Madrid          Real Madrid    4385
# Barcelona              Barcelona    4262
# Atletico Madrid  Atletico Madrid    3442
# Valencia                Valencia    3386
# Athletic Bilbao  Athletic Bilbao    3368

# %%
laliga.dtypes
# Out:
# Pos                   int64
# Team                 object
# Seasons               int64
# Points                int32
# GamesPlayed          object
# GamesWon             object
# GamesDrawn           object
# GamesLost            object
# GoalsFor             object
# GoalsAgainst         object
# Champion             object
# Runner-up            object
# Third                object
# Fourth               object
# Fifth                object
# Sixth                object
# T                    object
# Debut                object
# Since/LastApp        object
# BestPosition          int64
# Goals_Diff            int32
# GoalsDiff             int32
# WiningPercentage    float64
# dtype: object

# %%
laliga.loc[:,'Seasons':'GoalsAgainst']
# Out:
#                   Seasons  Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# Team
# Real Madrid            86    4385        2762     1647        552       563
# Barcelona              86    4262        2762     1581        573       608
# Atletico Madrid        80    3442        2614     1241        598       775
# Valencia               82    3386        2664     1187        616       861
# Athletic Bilbao        86    3368        2762     1209        633       920
# ...                   ...     ...         ...      ...        ...       ...
# Xerez                   1      34          38        8         10        20
# Condal                  1      22          30        7          8        15
# Atletico Tetuan         1      19          30        7          5        18
# Cultural Leonesa        1      14          30        5          4        21
# Girona                  1       0           0        0          0         0
#
#                  GoalsFor GoalsAgainst
# Team
# ...

# %%
laliga.iloc[:,2:10]
# Out:
#                   Seasons  Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# Team
# Real Madrid            86    4385        2762     1647        552       563
# Barcelona              86    4262        2762     1581        573       608
# Atletico Madrid        80    3442        2614     1241        598       775
# Valencia               82    3386        2664     1187        616       861
# Athletic Bilbao        86    3368        2762     1209        633       920
# ...                   ...     ...         ...      ...        ...       ...
# Xerez                   1      34          38        8         10        20
# Condal                  1      22          30        7          8        15
# Atletico Tetuan         1      19          30        7          5        18
# Cultural Leonesa        1      14          30        5          4        21
# Girona                  1       0           0        0          0         0
#
#                  GoalsFor GoalsAgainst
# Team
# ...

# %%
laliga.dtypes
# Out:
# Pos                   int64
# Team                 object
# Seasons               int64
# Points                int32
# GamesPlayed          object
# GamesWon             object
# GamesDrawn           object
# GamesLost            object
# GoalsFor             object
# GoalsAgainst         object
# Champion             object
# Runner-up            object
# Third                object
# Fourth               object
# Fifth                object
# Sixth                object
# T                    object
# Debut                object
# Since/LastApp        object
# BestPosition          int64
# Goals_Diff            int32
# GoalsDiff             int32
# WiningPercentage    float64
# dtype: object

# %%
laliga['Team'][laliga['Since/LastApp'].str.split('-').str[0].astype(int).between(1930,1980)]
# Out:
# Team
# Burgos CF                  Burgos CF
# Pontevedra                Pontevedra
# Arenas                        Arenas
# Alcoyano                    Alcoyano
# Jaen                            Jaen
# Real Union                Real Union
# AD Almeria                AD Almeria
# Europa                        Europa
# Condal                        Condal
# Atletico Tetuan      Atletico Tetuan
# Cultural Leonesa    Cultural Leonesa
# Name: Team, dtype: object

# %%
laliga.loc[['Real Madrid','Barcelona','Atletico Madrid'],:]
# Out:
#                  Pos             Team  Seasons  Points GamesPlayed GamesWon  \
# Team
# Real Madrid        1      Real Madrid       86    4385        2762     1647
# Barcelona          2        Barcelona       86    4262        2762     1581
# Atletico Madrid    3  Atletico Madrid       80    3442        2614     1241
#
#                 GamesDrawn GamesLost GoalsFor GoalsAgainst  ... Fourth Fifth  \
# Team                                                        ...
# Real Madrid            552       563     5947         3140  ...      8     3
# Barcelona              573       608     5900         3114  ...     12     4
# Atletico Madrid        598       775     4534         3309  ...      9     7
#
#                 Sixth   T Debut Since/LastApp BestPosition Goals_Diff  \
# Team
# Real Madrid         4  79  1929          1929            1       2807
# Barcelona           6  83  1929          1929            1       2786
# ...

# %%
laliga.loc[:,['Points','GamesPlayed']]
# Out:
#                   Points GamesPlayed
# Team
# Real Madrid         4385        2762
# Barcelona           4262        2762
# Atletico Madrid     3442        2614
# Valencia            3386        2664
# Athletic Bilbao     3368        2762
# ...                  ...         ...
# Xerez                 34          38
# Condal                22          30
# Atletico Tetuan       19          30
# Cultural Leonesa      14          30
# Girona                 0           0
#
# [61 rows x 2 columns]

# %%
laliga['Points'].astype('int')*2
# Out:
# Team
# Real Madrid         8770
# Barcelona           8524
# Atletico Madrid     6884
# Valencia            6772
# Athletic Bilbao     6736
#                     ...
# Xerez                 68
# Condal                44
# Atletico Tetuan       38
# Cultural Leonesa      28
# Girona                 0
# Name: Points, Length: 61, dtype: int32

# %%
laliga['GoalsFor'] = laliga['GoalsFor'].astype(int)
laliga['GoalsAgainst'] = laliga['GoalsAgainst'].astype(int)

# %%
def Goal_diff_count():
    GoalsperTeam=laliga[['Team','GoalsFor','GoalsAgainst']]
    GoalsperTeam=GoalsperTeam.set_index('Team')
    GoalsperTeam['Goalsdiff'] = GoalsperTeam['GoalsFor']-GoalsperTeam['GoalsAgainst']
    GoalsperTeam = GoalsperTeam.sort_values(by= ['Goalsdiff'], ascending = False)
    print(GoalsperTeam)
    print('Maximum Goal Difference and Team')
    print(GoalsperTeam['Goalsdiff'].max())
    print(GoalsperTeam.head(1))
    print('\n')
    print('Minimum Goal Difference and Team')
    print(GoalsperTeam['Goalsdiff'].min())
    print(GoalsperTeam.tail(1))

# %%
Goal_diff_count()
# Out:
#                   GoalsFor  GoalsAgainst  Goalsdiff
# Team
# Real Madrid           5947          3140       2807
# Barcelona             5900          3114       2786
# Atletico Madrid       4534          3309       1225
# Athletic Bilbao       4631          3700        931
# Valencia              4398          3469        929
# ...                    ...           ...        ...
# Murcia                 607           992       -385
# Las Palmas            1347          1746       -399
# Sporting Gijon        1753          2152       -399
# Valladolid            1767          2180       -413
# Racing Santander      1843          2368       -525
#
# [61 rows x 3 columns]
# Maximum Goal Difference and Team
# 2807
#              GoalsFor  GoalsAgainst  Goalsdiff
# Team
# Real Madrid      5947          3140       2807
#
#
# Minimum Goal Difference and Team
# -525
#                   GoalsFor  GoalsAgainst  Goalsdiff
# Team
# Racing Santander      1843          2368       -525
